# %%
import numpy as np 
import matplotlib.pyplot as plt 
 
 
x=np.array([1,2,3,4,5,6,7]) 
y=np.array([0,0,0,0,1,1,1]) 
 
 
def sigmoid(z): 
    return 1/(1+np.exp(-z)) 
 
 
m=0.0 
b=0.0 
L=0.1 
 
for i in range(1000): 
    z=m*x+b 
    y_pred=sigmoid(z) 
 
    dm=(-2/len(x))*np.sum(x*(y-y_pred)) 
    db=(-2/len(x))*np.sum((y-y_pred)) 
 
    m=m-L*dm 
    b=b-L*db 
 
    if i %100==0: 
        print(f"m={m}, b={b}") 
 
test=7 
z=m*test+b 
y_prediction=sigmoid(z) 
print(f"Prediction for {test} is {y_prediction}") 
 
 
xs=np.linspace(min(x)-1,max(x)+1,100) 
plt.scatter(test,y_prediction,color='green') 
plt.axhline(0.5,color='black') 
ys=sigmoid(m*xs+b) 
plt.plot(xs,ys,color='red')
# Out:
# m=0.11428571428571428, b=-0.014285714285714285
# m=0.6189964076294112, b=-2.419821187956299
# m=0.8961130549899151, b=-3.715683786796443
# m=1.089424608421547, b=-4.615285807802324
# m=1.2407525269655002, b=-5.317153284872793
# m=1.3667661483777522, b=-5.900033008348198
# m=1.475747417008988, b=-6.402990160996928
# m=1.5724195224772572, b=-6.848280910147208
# m=1.6597388643205668, b=-7.249822809593608
# m=1.7396838705598259, b=-7.616920563703896
# Prediction for 7 is 0.99131717180119
